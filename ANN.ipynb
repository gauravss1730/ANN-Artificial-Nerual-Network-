# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Churn.csv")
df.head(3)
df=df.drop(columns=["customerID","StreamingTV"])
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.isnull().sum()
df=df.dropna()

# %%
######For plotting all categorical variables
for i, col in enumerate(df.select_dtypes('object')):
    plt.figure(i)
    sns.countplot(x=col, data=df)

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 18
mosaic(df, ['Churn', 'InternetService']);
#People having fibre optic have churned the most

# %%
plt.rcParams['font.size'] = 15
mosaic(df, ['Churn', 'MultipleLines']);

# %%
plt.rcParams['font.size'] = 15
mosaic(df, ['Churn', 'PaymentMethod']);

# %%
df.StreamingMovies.value_counts()
#For Paper less Billing
df.loc[df.StreamingMovies== 'No internet service','StreamingMovies'] = 'No' 
df.loc[df.OnlineBackup== 'No internet service','OnlineBackup'] = 'No' 
df.loc[df.OnlineSecurity== 'No internet service','OnlineSecurity'] = 'No' 
df.loc[df.DeviceProtection== 'No internet service','DeviceProtection'] = 'No'
df.loc[df.TechSupport== 'No internet service','TechSupport'] = 'No'
df.loc[df.Churn== 'No','Churn'] = 0
df.loc[df.Churn== 'Yes','Churn'] = 1
x=df.drop(columns=["Churn"], axis=1)
y=df["Churn"]
#Checking the function
df.StreamingMovies.value_counts()
# Out:
# No     4301
# Yes    2731
# Name: StreamingMovies, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train = pd.get_dummies(x_train,columns=x_train.select_dtypes(include=['object']).columns,drop_first=True)
x_test = pd.get_dummies(x_test,columns=x_test.select_dtypes(include=['object']).columns,drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() 
# To scale data 

X_train=scaler.fit_transform(x_train)
X_test=scaler.fit_transform(x_test)

# %%
ann=tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=9,activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=9,activation='relu'))

# %% [markdown]
# Output layer

# %%
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
X=np.asarray(X_train).astype(np.float32) 
Y=np.asarray(y_train).astype(np.float32)


ann.fit(X, Y, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.5969 - accuracy: 0.7054
# Epoch 2/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.7339
# Epoch 3/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.7360
# Epoch 4/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4455 - accuracy: 0.7367
# Epoch 5/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4396 - accuracy: 0.7637
# Epoch 6/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4352 - accuracy: 0.7995
# Epoch 7/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.7995
# Epoch 8/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.8000
# Epoch 9/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4267 - accuracy: 0.8020
# Epoch 10/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4247 - accuracy: 0.7986
# Epoch 11/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4227 - accuracy: 0.8002
# Epoch 12/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8020
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8004
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.8023
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8020
# Epoch 16/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8018
# Epoch 17/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4153 - accuracy: 0.8025
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4143 - accuracy: 0.8011
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8037
# Epoch 20/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4130 - accuracy: 0.8027
# Epoch 21/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.8014
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4111 - accuracy: 0.8023
# Epoch 23/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4104 - accuracy: 0.8059
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4097 - accuracy: 0.8041
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4091 - accuracy: 0.8027
# Epoch 26/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8048
# Epoch 27/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8069
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4071 - accuracy: 0.8055
# Epoch 29/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4067 - accuracy: 0.8057
# Epoch 30/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8069
# Epoch 31/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8057
# Epoch 32/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.8075
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4046 - accuracy: 0.8059
# Epoch 34/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8059
# Epoch 35/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4040 - accuracy: 0.8071
# Epoch 36/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8080
# Epoch 37/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8084
# Epoch 38/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4026 - accuracy: 0.8071
# Epoch 39/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4019 - accuracy: 0.8087
# Epoch 40/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4017 - accuracy: 0.8085
# Epoch 41/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4014 - accuracy: 0.8103
# Epoch 42/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8085
# Epoch 43/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4005 - accuracy: 0.8087
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4002 - accuracy: 0.8092
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3998 - accuracy: 0.8084
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3999 - accuracy: 0.8116
# Epoch 47/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3990 - accuracy: 0.8116
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3988 - accuracy: 0.8092
# Epoch 49/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8096
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8107
# Epoch 51/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8096
# Epoch 52/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8112
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8119
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3966 - accuracy: 0.8121
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3963 - accuracy: 0.8130
# Epoch 56/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3961 - accuracy: 0.8126
# Epoch 57/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8121
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8101
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8128
# Epoch 60/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8119
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8158
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3946 - accuracy: 0.8126
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3945 - accuracy: 0.8098
# Epoch 64/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8117
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3938 - accuracy: 0.8140
# Epoch 66/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3940 - accuracy: 0.8124
# Epoch 67/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3935 - accuracy: 0.8117
# Epoch 68/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3933 - accuracy: 0.8135
# Epoch 69/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3933 - accuracy: 0.8149
# Epoch 70/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3932 - accuracy: 0.8149
# Epoch 71/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8162
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3927 - accuracy: 0.8140
# Epoch 73/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8148
# Epoch 74/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8165
# Epoch 75/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.8139
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3922 - accuracy: 0.8158
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8172
# Epoch 78/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3915 - accuracy: 0.8171
# Epoch 79/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8149
# Epoch 80/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3916 - accuracy: 0.8174
# Epoch 81/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3910 - accuracy: 0.8155
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.8158
# Epoch 83/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3908 - accuracy: 0.8174
# Epoch 84/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8162
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8160
# Epoch 86/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8139
# Epoch 87/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3903 - accuracy: 0.8176
# Epoch 88/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3901 - accuracy: 0.8162
# Epoch 89/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.8176
# Epoch 90/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3897 - accuracy: 0.8151
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3895 - accuracy: 0.8171
# Epoch 92/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3894 - accuracy: 0.8164
# Epoch 93/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8164
# Epoch 94/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3887 - accuracy: 0.8160
# Epoch 95/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3886 - accuracy: 0.8167
# Epoch 96/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8158
# Epoch 97/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3882 - accuracy: 0.8171
# Epoch 98/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8160
# Epoch 99/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8144
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3874 - accuracy: 0.8164

# %%
y_pred = ann.predict(X_test)

# %%
a=[]
for i in range(0,len(y_pred)):
  if y_pred[i]>0.5:
    a.append(1)
  else:
    a.append(0)

# %%
Y_test=np.asarray(y_test).astype(np.float32)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(Y_test, a) 
print(cm)
accuracy_score(Y_test, a)
# Out:
# [[911 127]
#  [154 215]]
# 0.8002842928216063
